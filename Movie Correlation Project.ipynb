# %%
# Import Libraries

import pandas as pd
import seaborn as sns
import numpy as np
from datetime import datetime

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the configuration of the plots we will create


# Read in the data

df = pd.read_csv(r'C:\Users\hanh2\Downloads\movies\movies.csv')

# %%
# Let's look at the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
# Let's see if there is any missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# Data types for our columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# change data types of columns

df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime yearcorrect
# 5445  2847246203  Twentieth Century Fox    162.0        2009
# 7445  2797501328         Marvel Studios    181.0        2019
# 3045  2201647264  Twentieth Century Fox    194.0        1997
# 6663  2069521700              Lucasfilm    138.0        2015
# 7244  2048359754         Marvel Studios    149.0        2018

# %%
df = df.fillna(0)

# %%
# Create correct Year column

df['yearcorrect'] = df['released'].astype(str).str.split(',').str[-1].str.strip().str[:4]

df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime yearcorrect
# 5445  2847246203  Twentieth Century Fox    162.0        2009
# 7445  2797501328         Marvel Studios    181.0        2019
# 3045  2201647264  Twentieth Century Fox    194.0        1997
# 6663  2069521700              Lucasfilm    138.0        2015
# 7244  2048359754         Marvel Studios    149.0        2018

# %% [markdown]
# df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
df = df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
pd.set_option('display.max_rows', None)

# %%
# Drop any duplicates

df['company'] = df['company'].astype(str)
df['company'].drop_duplicates().sort_values(ascending=False).head()
# Out:
# 2098    999
# 2225    998
# 1054    997
# 90      996
# 4636    995
# Name: company, dtype: object

# %%
df.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       6      0  2009       697    7.8  1100000.0      1155    1779
# 7445   535       6      0  2019       184    8.4   903000.0       162     744
# 3045  6896       6      6  1997       705    7.8  1100000.0      1155    1779
# 6663  5144       6      0  2015       699    7.8   876000.0      1125    2551
# 7244   536       6      0  2018       193    8.4   897000.0       162     744
#
#       star  country     budget       gross company  runtime  yearcorrect
# 5445  2335       56  237000000  2847246203    2254    162.0           30
# 7445  2242       56  356000000  2797501328    1607    181.0           40
# 3045  1596       56  200000000  2201647264    2254    194.0           18
# 6663   525       56  245000000  2069521700    1541    138.0           36
# 7244  2242       56  321000000  2048359754    1607    149.0           39

# %%
# Budget high correlation
# Company high correlation

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Budget for Film')

plt.ylabel('Gross Earnings')

plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime yearcorrect
# 5445  2847246203  Twentieth Century Fox    162.0        2009
# 7445  2797501328         Marvel Studios    181.0        2019
# 3045  2201647264  Twentieth Century Fox    194.0        1997
# 6663  2069521700              Lucasfilm    138.0        2015
# 7244  2048359754         Marvel Studios    149.0        2018

# %%
# Plot budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "green"}, line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Let's start looking at correlation

# %%
df.corr(method='pearson') #pearson, kendall, spearman
# Out:
# C:\Users\hanh2\AppData\Local\Temp\ipykernel_14208\4211989294.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson') #pearson, kendall, spearman
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.092616  0.222427  0.309212  0.261900  0.116358
# score    0.092616  1.000000  0.407101  0.056863  0.186012  0.394564
# votes    0.222427  0.407101  1.000000  0.486931  0.632870  0.306984
# budget   0.309212  0.056863  0.486931  1.000000  0.750157  0.268372
# gross    0.261900  0.186012  0.632870  0.750157  1.000000  0.244339
# runtime  0.116358  0.394564  0.306984  0.268372  0.244339  1.000000

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matric for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()
# Out:
# C:\Users\hanh2\AppData\Local\Temp\ipykernel_14208\2182186167.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr(method='pearson')

# %%
# Look at company

df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime yearcorrect
# 5445  2847246203  Twentieth Century Fox    162.0        2009
# 7445  2797501328         Marvel Studios    181.0        2019
# 3045  2201647264  Twentieth Century Fox    194.0        1997
# 6663  2069521700              Lucasfilm    138.0        2015
# 7244  2048359754         Marvel Studios    149.0        2018

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       6      0  2009       697    7.8  1100000.0      1155    1779
# 7445   535       6      0  2019       184    8.4   903000.0       162     744
# 3045  6896       6      6  1997       705    7.8  1100000.0      1155    1779
# 6663  5144       6      0  2015       699    7.8   876000.0      1125    2551
# 7244   536       6      0  2018       193    8.4   897000.0       162     744
#
#       star  country     budget       gross  company  runtime  yearcorrect
# 5445  2335       56  237000000  2847246203     2254    162.0           30
# 7445  2242       56  356000000  2797501328     1607    181.0           40
# 3045  1596       56  200000000  2201647264     2254    194.0           18
# 6663   525       56  245000000  2069521700     1541    138.0           36
# 7244  2242       56  321000000  2048359754     1607    149.0           39

# %%
df.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       6      0  2009       697    7.8  1100000.0      1155    1779
# 7445   535       6      0  2019       184    8.4   903000.0       162     744
# 3045  6896       6      6  1997       705    7.8  1100000.0      1155    1779
# 6663  5144       6      0  2015       699    7.8   876000.0      1125    2551
# 7244   536       6      0  2018       193    8.4   897000.0       162     744
#
#       star  country     budget       gross company  runtime  yearcorrect
# 5445  2335       56  237000000  2847246203    2254    162.0           30
# 7445  2242       56  356000000  2797501328    1607    181.0           40
# 3045  1596       56  200000000  2201647264    2254    194.0           18
# 6663   525       56  245000000  2069521700    1541    138.0           36
# 7244  2242       56  321000000  2048359754    1607    149.0           39

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matric for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.008069  0.016355  0.011453 -0.011311  0.016377
# rating      -0.008069  1.000000  0.072423  0.008779  0.016613  0.006192
# genre        0.016355  0.072423  1.000000 -0.081261  0.029822  0.027384
# year         0.011453  0.008779 -0.081261  1.000000 -0.000695  0.092616
# released    -0.011311  0.016613  0.029822 -0.000695  1.000000  0.039814
# score        0.016377  0.006192  0.027384  0.092616  0.039814  1.000000
# votes        0.013038  0.033743 -0.145296  0.222427  0.015878  0.407101
# director     0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.010568
# writer       0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.022098
# star         0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.000026
# country     -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133346
# budget       0.020548 -0.081939 -0.334021  0.309212  0.009145  0.056863
# gross        0.006989 -0.095450 -0.234297  0.261900  0.000519  0.186012
# company      0.009212 -0.032954 -0.071066 -0.010433 -0.010471  0.005067
# runtime      0.008483  0.064133 -0.052914  0.116358  0.004852  0.394564
# yearcorrect  0.011711  0.006560 -0.064337  0.962250 -0.003433  0.101300
#
#                 votes  director    writer      star   country    budget  \
# name         0.013038  0.009079  0.009081  0.006472 -0.010737  0.020548
# rating       0.033743  0.019483 -0.005921  0.013405  0.081244 -0.081939
# genre       -0.145296 -0.015258  0.006567 -0.005477 -0.037615 -0.334021
# year         0.222427 -0.020795 -0.008656 -0.027242 -0.070938  0.309212
# released     0.015878 -0.001478 -0.002404  0.015777 -0.020427  0.009145
# score        0.407101  0.010568  0.022098 -0.000026 -0.133346  0.056863
# votes        1.000000  0.000349  0.001127 -0.019146  0.073525  0.486931
# director     0.000349  1.000000  0.299067  0.039234  0.017490  0.004976
# writer       0.001127  0.299067  1.000000  0.027245  0.015343 -0.025911
# star        -0.019146  0.039234  0.027245  1.000000 -0.012998 -0.019952
# country      0.073525  0.017490  0.015343 -0.012998  1.000000  0.131720
# budget       0.486931  0.004976 -0.025911 -0.019952  0.131720  1.000000
# gross        0.632870 -0.014916 -0.022997 -0.001129  0.095325  0.750157
# company      0.133455  0.004404  0.005644  0.012437  0.095546  0.186472
# runtime      0.306984  0.017062 -0.004036  0.009418 -0.073319  0.268372
# yearcorrect  0.204808 -0.021652 -0.010438 -0.030390 -0.092522  0.282506
#
#                 gross   company   runtime  yearcorrect
# name         0.006989  0.009212  0.008483     0.011711
# rating      -0.095450 -0.032954  0.064133     0.006560
# genre       -0.234297 -0.071066 -0.052914    -0.064337
# year         0.261900 -0.010433  0.116358     0.962250
# released     0.000519 -0.010471  0.004852    -0.003433
# score        0.186012  0.005067  0.394564     0.101300
# votes        0.632870  0.133455  0.306984     0.204808
# director    -0.014916  0.004404  0.017062    -0.021652
# writer      -0.022997  0.005644 -0.004036    -0.010438
# star        -0.001129  0.012437  0.009418    -0.030390
# country      0.095325  0.095546 -0.073319    -0.092522
# budget       0.750157  0.186472  0.268372     0.282506
# gross        1.000000  0.156743  0.244339     0.241832
# company      0.156743  1.000000  0.037527    -0.027172
# runtime      0.244339  0.037527  1.000000     0.107197
# yearcorrect  0.241832 -0.027172  0.107197     1.000000

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#              score          0.016377
#              votes          0.013038
#              director       0.009079
#              writer         0.009081
#              star           0.006472
#              country       -0.010737
#              budget         0.020548
#              gross          0.006989
#              company        0.009212
#              runtime        0.008483
#              yearcorrect    0.011711
# rating       name          -0.008069
#              rating         1.000000
#              genre          0.072423
#              year           0.008779
#              released       0.016613
#              score          0.006192
#              votes          0.033743
#              director       0.019483
#              writer        -0.005921
#              star           0.013405
#              country        0.081244
#              budget        -0.081939
#              gross         -0.095450
#              company       -0.032954
#              runtime        0.064133
#              yearcorrect    0.006560
# genre        name           0.016355
#              rating         0.072423
#              genre          1.000000
#              year          -0.081261
#              released       0.029822
#              score          0.027384
#              votes         -0.145296
#              director      -0.015258
#              writer         0.006567
#              star          -0.005477
#              country       -0.037615
#              budget        -0.334021
#              gross         -0.234297
#              company       -0.071066
#              runtime       -0.052914
#              yearcorrect   -0.064337
# year         name           0.011453
#              rating         0.008779
#              genre         -0.081261
#              year           1.000000
#              released      -0.000695
#              score          0.092616
#              votes          0.222427
#              director      -0.020795
#              writer        -0.008656
#              star          -0.027242
#              country       -0.070938
#              budget         0.309212
#              gross          0.261900
#              company       -0.010433
#              runtime        0.116358
#              yearcorrect    0.962250
# released     name          -0.011311
#              rating         0.016613
#              genre          0.029822
#              year          -0.000695
#              released       1.000000
#              score          0.039814
#              votes          0.015878
#              director      -0.001478
#              writer        -0.002404
#              star           0.015777
#              country       -0.020427
#              budget         0.009145
#              gross          0.000519
#              company       -0.010471
#              runtime        0.004852
#              yearcorrect   -0.003433
# score        name           0.016377
#              rating         0.006192
#              genre          0.027384
#              year           0.092616
#              released       0.039814
#              score          1.000000
#              votes          0.407101
#              director       0.010568
#              writer         0.022098
#              star          -0.000026
#              country       -0.133346
#              budget         0.056863
#              gross          0.186012
#              company        0.005067
#              runtime        0.394564
#              yearcorrect    0.101300
# votes        name           0.013038
#              rating         0.033743
#              genre         -0.145296
#              year           0.222427
#              released       0.015878
#              score          0.407101
#              votes          1.000000
#              director       0.000349
#              writer         0.001127
#              star          -0.019146
#              country        0.073525
#              budget         0.486931
#              gross          0.632870
#              company        0.133455
#              runtime        0.306984
#              yearcorrect    0.204808
# director     name           0.009079
#              rating         0.019483
#              genre         -0.015258
#              year          -0.020795
#              released      -0.001478
#              score          0.010568
#              votes          0.000349
#              director       1.000000
#              writer         0.299067
#              star           0.039234
#              country        0.017490
#              budget         0.004976
#              gross         -0.014916
#              company        0.004404
#              runtime        0.017062
#              yearcorrect   -0.021652
# writer       name           0.009081
#              rating        -0.005921
#              genre          0.006567
#              year          -0.008656
#              released      -0.002404
#              score          0.022098
#              votes          0.001127
#              director       0.299067
#              writer         1.000000
#              star           0.027245
#              country        0.015343
#              budget        -0.025911
#              gross         -0.022997
#              company        0.005644
#              runtime       -0.004036
#              yearcorrect   -0.010438
# star         name           0.006472
#              rating         0.013405
#              genre         -0.005477
#              year          -0.027242
#              released       0.015777
#              score         -0.000026
#              votes         -0.019146
#              director       0.039234
#              writer         0.027245
#              star           1.000000
#              country       -0.012998
#              budget        -0.019952
#              gross         -0.001129
#              company        0.012437
#              runtime        0.009418
#              yearcorrect   -0.030390
# country      name          -0.010737
#              rating         0.081244
#              genre         -0.037615
#              year          -0.070938
#              released      -0.020427
#              score         -0.133346
#              votes          0.073525
#              director       0.017490
#              writer         0.015343
#              star          -0.012998
#              country        1.000000
#              budget         0.131720
#              gross          0.095325
#              company        0.095546
#              runtime       -0.073319
#              yearcorrect   -0.092522
# budget       name           0.020548
#              rating        -0.081939
#              genre         -0.334021
#              year           0.309212
#              released       0.009145
#              score          0.056863
#              votes          0.486931
#              director       0.004976
#              writer        -0.025911
#              star          -0.019952
#              country        0.131720
#              budget         1.000000
#              gross          0.750157
#              company        0.186472
#              runtime        0.268372
#              yearcorrect    0.282506
# gross        name           0.006989
#              rating        -0.095450
#              genre         -0.234297
#              year           0.261900
#              released       0.000519
#              score          0.186012
#              votes          0.632870
#              director      -0.014916
#              writer        -0.022997
#              star          -0.001129
#              country        0.095325
#              budget         0.750157
#              gross          1.000000
#              company        0.156743
#              runtime        0.244339
#              yearcorrect    0.241832
# company      name           0.009212
#              rating        -0.032954
#              genre         -0.071066
#              year          -0.010433
#              released      -0.010471
#              score          0.005067
#              votes          0.133455
#              director       0.004404
#              writer         0.005644
#              star           0.012437
#              country        0.095546
#              budget         0.186472
#              gross          0.156743
#              company        1.000000
#              runtime        0.037527
#              yearcorrect   -0.027172
# runtime      name           0.008483
#              rating         0.064133
#              genre         -0.052914
#              year           0.116358
#              released       0.004852
#              score          0.394564
#              votes          0.306984
#              director       0.017062
#              writer        -0.004036
#              star           0.009418
#              country       -0.073319
#              budget         0.268372
#              gross          0.244339
#              company        0.037527
#              runtime        1.000000
#              yearcorrect    0.107197
# yearcorrect  name           0.011711
#              rating         0.006560
#              genre         -0.064337
#              year           0.962250
#              released      -0.003433
#              score          0.101300
#              votes          0.204808
#              director      -0.021652
#              writer        -0.010438
#              star          -0.030390
#              country       -0.092522
#              budget         0.282506
#              gross          0.241832
#              company       -0.027172
#              runtime        0.107197
#              yearcorrect    1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.334021
# budget       genre         -0.334021
# genre        gross         -0.234297
# gross        genre         -0.234297
# genre        votes         -0.145296
# votes        genre         -0.145296
# country      score         -0.133346
# score        country       -0.133346
# rating       gross         -0.095450
# gross        rating        -0.095450
# yearcorrect  country       -0.092522
# country      yearcorrect   -0.092522
# rating       budget        -0.081939
# budget       rating        -0.081939
# genre        year          -0.081261
# year         genre         -0.081261
# country      runtime       -0.073319
# runtime      country       -0.073319
# genre        company       -0.071066
# company      genre         -0.071066
# country      year          -0.070938
# year         country       -0.070938
# genre        yearcorrect   -0.064337
# yearcorrect  genre         -0.064337
# genre        runtime       -0.052914
# runtime      genre         -0.052914
# country      genre         -0.037615
# genre        country       -0.037615
# company      rating        -0.032954
# rating       company       -0.032954
# star         yearcorrect   -0.030390
# yearcorrect  star          -0.030390
# star         year          -0.027242
# year         star          -0.027242
# yearcorrect  company       -0.027172
# company      yearcorrect   -0.027172
# writer       budget        -0.025911
# budget       writer        -0.025911
# writer       gross         -0.022997
# gross        writer        -0.022997
# director     yearcorrect   -0.021652
# yearcorrect  director      -0.021652
# year         director      -0.020795
# director     year          -0.020795
# released     country       -0.020427
# country      released      -0.020427
# budget       star          -0.019952
# star         budget        -0.019952
#              votes         -0.019146
# votes        star          -0.019146
# director     genre         -0.015258
# genre        director      -0.015258
# director     gross         -0.014916
# gross        director      -0.014916
# country      star          -0.012998
# star         country       -0.012998
# released     name          -0.011311
# name         released      -0.011311
# country      name          -0.010737
# name         country       -0.010737
# released     company       -0.010471
# company      released      -0.010471
# yearcorrect  writer        -0.010438
# writer       yearcorrect   -0.010438
# year         company       -0.010433
# company      year          -0.010433
# writer       year          -0.008656
# year         writer        -0.008656
# name         rating        -0.008069
# rating       name          -0.008069
#              writer        -0.005921
# writer       rating        -0.005921
# star         genre         -0.005477
# genre        star          -0.005477
# runtime      writer        -0.004036
# writer       runtime       -0.004036
# yearcorrect  released      -0.003433
# released     yearcorrect   -0.003433
#              writer        -0.002404
# writer       released      -0.002404
# director     released      -0.001478
# released     director      -0.001478
# star         gross         -0.001129
# gross        star          -0.001129
# released     year          -0.000695
# year         released      -0.000695
# star         score         -0.000026
# score        star          -0.000026
# votes        director       0.000349
# director     votes          0.000349
# released     gross          0.000519
# gross        released       0.000519
# writer       votes          0.001127
# votes        writer         0.001127
# director     company        0.004404
# company      director       0.004404
# released     runtime        0.004852
# runtime      released       0.004852
# budget       director       0.004976
# director     budget         0.004976
# score        company        0.005067
# company      score          0.005067
# writer       company        0.005644
# company      writer         0.005644
# score        rating         0.006192
# rating       score          0.006192
# star         name           0.006472
# name         star           0.006472
# yearcorrect  rating         0.006560
# rating       yearcorrect    0.006560
# writer       genre          0.006567
# genre        writer         0.006567
# gross        name           0.006989
# name         gross          0.006989
# runtime      name           0.008483
# name         runtime        0.008483
# year         rating         0.008779
# rating       year           0.008779
# director     name           0.009079
# name         director       0.009079
#              writer         0.009081
# writer       name           0.009081
# budget       released       0.009145
# released     budget         0.009145
# company      name           0.009212
# name         company        0.009212
# runtime      star           0.009418
# star         runtime        0.009418
# director     score          0.010568
# score        director       0.010568
# year         name           0.011453
# name         year           0.011453
# yearcorrect  name           0.011711
# name         yearcorrect    0.011711
# company      star           0.012437
# star         company        0.012437
# name         votes          0.013038
# votes        name           0.013038
# rating       star           0.013405
# star         rating         0.013405
# writer       country        0.015343
# country      writer         0.015343
# released     star           0.015777
# star         released       0.015777
# released     votes          0.015878
# votes        released       0.015878
# genre        name           0.016355
# name         genre          0.016355
#              score          0.016377
# score        name           0.016377
# released     rating         0.016613
# rating       released       0.016613
# director     runtime        0.017062
# runtime      director       0.017062
# director     country        0.017490
# country      director       0.017490
# rating       director       0.019483
# director     rating         0.019483
# name         budget         0.020548
# budget       name           0.020548
# writer       score          0.022098
# score        writer         0.022098
# writer       star           0.027245
# star         writer         0.027245
# genre        score          0.027384
# score        genre          0.027384
# released     genre          0.029822
# genre        released       0.029822
# votes        rating         0.033743
# rating       votes          0.033743
# runtime      company        0.037527
# company      runtime        0.037527
# director     star           0.039234
# star         director       0.039234
# released     score          0.039814
# score        released       0.039814
# budget       score          0.056863
# score        budget         0.056863
# runtime      rating         0.064133
# rating       runtime        0.064133
# genre        rating         0.072423
# rating       genre          0.072423
# country      votes          0.073525
# votes        country        0.073525
# country      rating         0.081244
# rating       country        0.081244
# year         score          0.092616
# score        year           0.092616
# country      gross          0.095325
# gross        country        0.095325
# country      company        0.095546
# company      country        0.095546
# score        yearcorrect    0.101300
# yearcorrect  score          0.101300
# runtime      yearcorrect    0.107197
# yearcorrect  runtime        0.107197
# year         runtime        0.116358
# runtime      year           0.116358
# budget       country        0.131720
# country      budget         0.131720
# votes        company        0.133455
# company      votes          0.133455
#              gross          0.156743
# gross        company        0.156743
# score        gross          0.186012
# gross        score          0.186012
# budget       company        0.186472
# company      budget         0.186472
# votes        yearcorrect    0.204808
# yearcorrect  votes          0.204808
# year         votes          0.222427
# votes        year           0.222427
# gross        yearcorrect    0.241832
# yearcorrect  gross          0.241832
# runtime      gross          0.244339
# gross        runtime        0.244339
#              year           0.261900
# year         gross          0.261900
# budget       runtime        0.268372
# runtime      budget         0.268372
# yearcorrect  budget         0.282506
# budget       yearcorrect    0.282506
# director     writer         0.299067
# writer       director       0.299067
# runtime      votes          0.306984
# votes        runtime        0.306984
# budget       year           0.309212
# year         budget         0.309212
# score        runtime        0.394564
# runtime      score          0.394564
# votes        score          0.407101
# score        votes          0.407101
# budget       votes          0.486931
# votes        budget         0.486931
#              gross          0.632870
# gross        votes          0.632870
# budget       gross          0.750157
# gross        budget         0.750157
# yearcorrect  year           0.962250
# year         yearcorrect    0.962250
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# votes        gross          0.632870
# gross        votes          0.632870
# budget       gross          0.750157
# gross        budget         0.750157
# yearcorrect  year           0.962250
# year         yearcorrect    0.962250
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
# Votes and budget have the highest correlation to gross earnings
